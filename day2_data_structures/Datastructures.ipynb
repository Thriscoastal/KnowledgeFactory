# %% [markdown]
# List Tuples Dictonary

# %%
#List
list = []
list.append(1)
list
# Out:
# [1]

# %%
list.append(2)
list.append(3)
list.append(4)
list.append(5)

# %%
print(list.pop(2))
# Out:
# 3

# %%
list.insert(2,3)

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append(list)

# %%
list
# Out:
# [1, 2, 3, 4, 5, [...]]

# %%
list[5]
# Out:
# [1, 2, 3, 4, 5, [...]]

# %%
list[1]
# Out:
# 2

# %%
list=[1,2,3]

# %%
dict={'Thrishal':7003}

# %%
dict['Thrishal']
# Out:
# 7003

# %%
dict['Shyam']=9669

# %%
dict['Praneeth'] = 7003

# %%
dict['Praneeth'] = 7037

# %%
user_profile = {"username": "Thrishal"}

# %%
name = user_profile.setdefault("username", "Guest User")

# %%
print(name)
# Out:
# Thrishal

# %%
print(user_profile)
# Out:
# {'username': 'Thrishal'}

# %%
current_theme = user_profile.setdefault("theme", "dark")

# %%
print(current_theme)
# Out:
# dark

# %%
print(user_profile)
# Out:
# {'username': 'Thrishal', 'theme': 'dark'}

# %%
user_profile.keys()
# Out:
# dict_keys(['username', 'theme'])

# %%
user_profile.values()
# Out:
# dict_values(['Thrishal', 'dark'])

# %%
user_profile.items()
# Out:
# dict_items([('username', 'Thrishal'), ('theme', 'dark')])

# %%
user_profile.update({"age": 25, "location": "India"})

# %%
user_profile
# Out:
# {'username': 'Thrishal', 'theme': 'dark', 'age': 25, 'location': 'India'}

# %%
removed_item = user_profile.pop("age")

# %%
print("Removed:", removed_item)
# Out:
# Removed: 25

# %%
user_profile.popitem()
# Out:
# ('location', 'India')

# %%
user_profile
# Out:
# {'username': 'Thrishal', 'theme': 'dark'}

# %%
user_profile.clear()

# %%
my_tuple = (10, 20, 30, 40)

# %%
my_tuple[1]
# Out:
# 20

# %%
my_tuple[-1]
# Out:
# 40

# %%
my_tuple[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 my_tuple[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
single_tuple = (50,)

# %%
type(single_tuple)
# Out:
# tuple

# %%
a, b, c, d = my_tuple

# %%
print(a, b)
# Out:
# 10 20

# %%
repeated_tuple = my_tuple * 2

# %%
repeated_tuple
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %%
repeated_tuple.count(20) # Count occurrences of 20
# Out:
# 2

# %%
repeated_tuple.index(30) # Find the first index of 30
# Out:
# 2

# %%
nums = [1, 2, 3, 4, 5]

# %%
squares = [x * x for x in nums]

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
evens = [x for x in range(10) if x % 2 == 0]

# %%
evens
# Out:
# [0, 2, 4, 6, 8]

# %%
dict_comp = {x: x**2 for x in range(1, 6)}

# %%
dict_comp
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
set_comp = {x % 3 for x in range(10)}

# %%
set_comp
# Out:
# {0, 1, 2}

# %%
names = ["Thrishal", "Shyam", "Praneeth"]

# %%
name_lengths = {name: len(name) for name in names}

# %%
name_lengths
# Out:
# {'Thrishal': 8, 'Shyam': 5, 'Praneeth': 8}
