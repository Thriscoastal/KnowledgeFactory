# %% [markdown]
# # Day 1: Learning Python basics

# %%
x = 5
print(x)
# Out:
# 5

# %%
y = 2.5
print(y)
# Out:
# 2.5

# %%
ans = x + y
print(ans)
# Out:
# 7.5

# %%
high_score = 100
print(high_score)
# Out:
# 100

# %%
negative_num = -50
print(negative_num)
# Out:
# -50

# %%
print(10 / 3)
# Out:
# 3.3333333333333335

# %%
print(10 // 3)
# Out:
# 3

# %%
print(2 ** 3)
# Out:
# 8

# %%
remainder = 10 % 3
print(remainder)
# Out:
# 1

# %%
big_num = 1000 + 2000 * 2
print(big_num)
# Out:
# 5000

# %%
my_name = "Thrishal"
print(my_name)
# Out:
# Thrishal

# %%
greeting = 'Hello there'
print(greeting)
# Out:
# Hello there

# %%
combined = greeting + my_name
print(combined)
# Out:
# Hello thereThrishal

# %%
fixed = greeting + " " + my_name
print(fixed)
# Out:
# Hello there Thrishal

# %%
shout = "ahhh " * 3
print(shout)
# Out:
# ahhh ahhh ahhh

# %%
num_text = "10"
# print(num_text + 5)

# %%
fixed_num = int(num_text) + 5
print(fixed_num)
# Out:
# 15

# %%
age = 20

# %%
fixed_age = "I am " + str(age)
print(fixed_age)
# Out:
# I am 20

# %%
print(len("python"))
# Out:
# 6

# %%
is_it_raining = False
print(is_it_raining)
# Out:
# False

# %%
is_it_sunny = True
print(is_it_sunny)
# Out:
# True

# %%
print(5 > 3)
# Out:
# True

# %%
print(10 == 10)
# Out:
# True

# %%
print(10 != 9)
# Out:
# True

# %%
check_and = (5 > 3) and (10 < 20)
print(check_and)
# Out:
# True

# %%
check_or = (5 > 10) or (10 < 20)
print(check_or)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
guess = "apple"
print(guess == "banana")
# Out:
# False

# %%
print("cat" in "catastrophe")
# Out:
# True

# %%
fav_colors = ["red", "blue", "green"]
print(fav_colors)
# Out:
# ['red', 'blue', 'green']

# %%
print(fav_colors[0])
# Out:
# red

# %%
print(fav_colors[2])
# Out:
# green

# %%
fav_colors.append("yellow")
print(fav_colors)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %%
print(len(fav_colors))
# Out:
# 4

# %%
fav_colors.remove("blue")
print(fav_colors)
# Out:
# ['red', 'green', 'yellow']

# %%
mixed_list = [1, "hello", True]
print(mixed_list)
# Out:
# [1, 'hello', True]

# %%
numbers_list = [10, 20, 30]
numbers_list[1] = 99
print(numbers_list)
# Out:
# [10, 99, 30]

# %%
print(numbers_list[-1])
# Out:
# 30

# %%
empty_list = []
print(empty_list)
# Out:
# []

# %%
phone_book = {"mother": 1234, "father": 5678}
print(phone_book)
# Out:
# {'mother': 1234, 'father': 5678}

# %%
print(phone_book["mother"])
# Out:
# 1234

# %%
phone_book["sister"] = 9999
print(phone_book)
# Out:
# {'mother': 1234, 'father': 5678, 'sister': 9999}

# %%
phone_book["mother"] = 5555
print(phone_book)
# Out:
# {'mother': 5555, 'father': 5678, 'sister': 9999}

# %%
print("mother" in phone_book)
# Out:
# True

# %%
marks = 75
if marks >= 50:
    print("Passed!")
# Out:
# Passed!

# %%
temperature = 15
if temperature > 30:
    print("Hot")
else:
    print("Not hot")
# Out:
# Not hot

# %%
speed = 45
if speed > 60:
    print("Too fast")
elif speed < 30:
    print("Too slow")
else:
    print("Perfect speed")
# Out:
# Perfect speed

# %%
is_weekend = True
if not is_weekend:
    print("Go to school")
else:
    print("Sleep in")
# Out:
# Sleep in

# %%
num = 15
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
for num in [1, 2, 3]:
    print("Loop count: " + str(num))
# Out:
# Loop count: 1
# Loop count: 2
# Loop count: 3

# %%
total_sum = 0
for n in [5, 10, 15]:
    total_sum = total_sum + n
print(total_sum)
# Out:
# 30

# %%
count = 0
while count < 3:
    print("Count is " + str(count))
    count = count + 1
# Out:
# Count is 0
# Count is 1
# Count is 2

# %%
word = "abc"
for letter in word:
    print(letter)
# Out:
# a
# b
# c

# %%
def say_hi():
    print("Hi there!")
say_hi()
# Out:
# Hi there!

# %%
def double_me(val):
    print(val * 2)
double_me(10)
# Out:
# 20

# %%
def add_nums(a, b):
    return a + b
result = add_nums(4, 5)
print(result)
# Out:
# 9

# %%
def check_voter(age):
    if age >= 18:
        return True
    else:
        return False
print(check_voter(16))
# Out:
# False

# %%
try:
    print(unmade_variable)
except:
    print("Oops that variable doesn't exist yet!")
# Out:
# Oops that variable doesn't exist yet!

# %%
# Cell 60: catching an index crash block
try:
    bad_list = [1, 2]
    print(bad_list[5])
except:
    print("Index out of bounds caught!")
# Out:
# Index out of bounds caught!
